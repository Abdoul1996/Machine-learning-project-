# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdoul1996/Machine-learning-project-/blob/main/Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Pandas: Two dimentional table of data(row, col)
# DataFrame(row, col)
# Series(one dimentional)

pd.options.display.float_format = '{:.2f}'.format # display two digits decimal places
pd.options.display.max_rows = 20

# %%
cols = ['symboling', 'losses', 'make', 'fuel-type', 'aspiration', 'num-doors',
        'body-style', 'drive-wheels', 'engine-location', 'wheel-base',
        'length', 'width', 'height', 'weight', 'engine-type', 'num-cylinders',
        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']

# %%
# CSV doesn't have a header row
car_data = pd.read_csv('https://storage.googleapis.com/ml_universities/cars_dataset/cars_data.csv', sep=',', names=cols, header=None, encoding='latin-1')

# %%
import fnmatch  # fnmatch is used to test if a string matches given pattern
import math

from IPython import display # displaying different type of data
from matplotlib import cm     # colormap function : cm can be used to map data values to colors
from matplotlib import pyplot as plt  # figures and subplots

import numpy as np  # multidimentional array objects
import pandas as pd #  data analysis and manipulating library python. Provides data structure

from sklearn import metrics
import tensorflow as tf
from tensorflow.python.data import Dataset

tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
print("Done with the imports")
# Out:
# Done with the imports

# %%
car_data.head()
# Out:
#    symboling losses         make fuel-type aspiration num-doors   body-style  \
# 0          3      ?  alfa-romero       gas        std       two  convertible
# 1          3      ?  alfa-romero       gas        std       two  convertible
# 2          1      ?  alfa-romero       gas        std       two    hatchback
# 3          2    164         audi       gas        std      four        sedan
# 4          2    164         audi       gas        std      four        sedan
#
#   drive-wheels engine-location  wheel-base  ...  engine-size  fuel-system  \
# 0          rwd           front       88.60  ...          130         mpfi
# 1          rwd           front       88.60  ...          130         mpfi
# 2          rwd           front       94.50  ...          152         mpfi
# 3          fwd           front       99.80  ...          109         mpfi
# 4          4wd           front       99.40  ...          136         mpfi
#
# ...

# %%
car_data.shape
# Out:
# (205, 26)

# %%
# np.random.permutation() takes index and randomly shuffles the order of the element
# DataFrame.reindex() creating a new index
car_data = car_data.reindex(np.random.permutation(car_data.index))

# %%
car_data.head()
# Out:
#      symboling losses        make fuel-type aspiration num-doors body-style  \
# 76           2    161  mitsubishi       gas        std       two  hatchback
# 145          0    102      subaru       gas      turbo      four      sedan
# 40           0     85       honda       gas        std      four      sedan
# 38           0    106       honda       gas        std       two  hatchback
# 53           1    113       mazda       gas        std      four      sedan
#
#     drive-wheels engine-location  wheel-base  ...  engine-size  fuel-system  \
# 76           fwd           front       93.70  ...           92         2bbl
# 145          4wd           front       97.00  ...          108         mpfi
# 40           fwd           front       96.50  ...          110         1bbl
# 38           fwd           front       96.50  ...          110         1bbl
# 53           fwd           front       93.10  ...           91         2bbl
#
# ...

# %%
car_data.isnull().sum()
# Out:
# symboling      0
# losses         0
# make           0
# fuel-type      0
# aspiration     0
#               ..
# horsepower     0
# peak-rpm       0
# city-mpg       0
# highway-mpg    0
# price          0
# Length: 26, dtype: int64

# %%
# In order to check Statistics about the data
# Mean : average of datasets
# std : Standard Deviation

car_data.describe()
# Out:
#        symboling  wheel-base  length  width  height  weight  engine-size  \
# count     205.00      205.00  205.00 205.00  205.00  205.00       205.00
# mean        0.83       98.76  174.05  65.91   53.72 2555.57       126.91
# std         1.25        6.02   12.34   2.15    2.44  520.68        41.64
# min        -2.00       86.60  141.10  60.30   47.80 1488.00        61.00
# 25%         0.00       94.50  166.30  64.10   52.00 2145.00        97.00
# 50%         1.00       97.00  173.20  65.50   54.10 2414.00       120.00
# 75%         2.00      102.40  183.10  66.90   55.50 2935.00       141.00
# max         3.00      120.90  208.10  72.30   59.80 4066.00       326.00
#
#        compression-ratio  city-mpg  highway-mpg
# count             205.00    205.00       205.00
# mean               10.14     25.22        30.75
# std                 3.97      6.54         6.89
# min                 7.00     13.00        16.00
# 25%                 8.60     19.00        25.00
# ...

# %%
numbers = [2,3,2,5] # Average number
mean = np.mean(numbers)
print(mean)
# Out:
# 3.0

# %% [markdown]
# # **Preprocessing Step**

# %%
# Standard Diviation is a measure of how spread out set of number is

std = np.std(numbers)
print(std)
# Out:
# 1.224744871391589

# %%
car_data.replace('?', np.nan, inplace=True)

# %%
car_data.head(10)
# Out:
#      symboling losses        make fuel-type aspiration num-doors body-style  \
# 76           2    161  mitsubishi       gas        std       two  hatchback
# 145          0    102      subaru       gas      turbo      four      sedan
# 40           0     85       honda       gas        std      four      sedan
# 38           0    106       honda       gas        std       two  hatchback
# 53           1    113       mazda       gas        std      four      sedan
# 204         -1     95       volvo       gas      turbo      four      sedan
# 134          3    150        saab       gas        std       two  hatchback
# 181         -1    NaN      toyota       gas        std      four      wagon
# 127          3    NaN     porsche       gas        std       two    hardtop
# 61           1    129       mazda       gas        std       two  hatchback
#
#     drive-wheels engine-location  wheel-base  ...  engine-size  fuel-system  \
# ...

# %%
#car_data.replace('?', np.nan, inplace=True) # replace missing values
car_data['price'] = pd.to_numeric(car_data['price'], errors = 'coerce') # to_numeric convert to a numeric data type

# %%
car_data['losses'] = pd.to_numeric(car_data['losses'], errors= 'coerce')
car_data['horsepower'] = pd.to_numeric(car_data['horsepower'], errors = 'coerce')
car_data['peak-rpm'] = pd.to_numeric(car_data['peak-rpm'], errors='coerce')
car_data['city-mpg'] = pd.to_numeric(car_data['city-mpg'], errors='coerce')
car_data['highway-mpg'] = pd.to_numeric(car_data['highway-mpg'], errors='coerce')
car_data['losses'] = pd.to_numeric(car_data['losses'], errors='coerce')

# %%
car_data.describe()
# Out:
#        symboling  losses  wheel-base  length  width  height  weight  \
# count     205.00  164.00      205.00  205.00 205.00  205.00  205.00
# mean        0.83  122.00       98.76  174.05  65.91   53.72 2555.57
# std         1.25   35.44        6.02   12.34   2.15    2.44  520.68
# min        -2.00   65.00       86.60  141.10  60.30   47.80 1488.00
# 25%         0.00   94.00       94.50  166.30  64.10   52.00 2145.00
# 50%         1.00  115.00       97.00  173.20  65.50   54.10 2414.00
# 75%         2.00  150.00      102.40  183.10  66.90   55.50 2935.00
# max         3.00  256.00      120.90  208.10  72.30   59.80 4066.00
#
#        engine-size  compression-ratio  horsepower  peak-rpm  city-mpg  \
# count       205.00             205.00      203.00    203.00    205.00
# mean        126.91              10.14      104.26   5125.37     25.22
# std          41.64               3.97       39.71    479.33      6.54
# min          61.00               7.00       48.00   4150.00     13.00
# ...

# %%
car_data.head(10)
# Out:
#      symboling  losses        make fuel-type aspiration num-doors body-style  \
# 76           2  161.00  mitsubishi       gas        std       two  hatchback
# 145          0  102.00      subaru       gas      turbo      four      sedan
# 40           0   85.00       honda       gas        std      four      sedan
# 38           0  106.00       honda       gas        std       two  hatchback
# 53           1  113.00       mazda       gas        std      four      sedan
# 204         -1   95.00       volvo       gas      turbo      four      sedan
# 134          3  150.00        saab       gas        std       two  hatchback
# 181         -1     NaN      toyota       gas        std      four      wagon
# 127          3     NaN     porsche       gas        std       two    hardtop
# 61           1  129.00       mazda       gas        std       two  hatchback
#
#     drive-wheels engine-location  wheel-base  ...  engine-size  fuel-system  \
# ...

# %%
# Replace NAN to 0

# %%
# mode (most frequent values )
car_data.fillna(car_data.mode().iloc[0], inplace=True)

# %%
car_data.head(10)
# Out:
#      symboling  losses        make fuel-type aspiration num-doors body-style  \
# 76           2  161.00  mitsubishi       gas        std       two  hatchback
# 145          0  102.00      subaru       gas      turbo      four      sedan
# 40           0   85.00       honda       gas        std      four      sedan
# 38           0  106.00       honda       gas        std       two  hatchback
# 53           1  113.00       mazda       gas        std      four      sedan
# 204         -1   95.00       volvo       gas      turbo      four      sedan
# 134          3  150.00        saab       gas        std       two  hatchback
# 181         -1  161.00      toyota       gas        std      four      wagon
# 127          3  161.00     porsche       gas        std       two    hardtop
# 61           1  129.00       mazda       gas        std       two  hatchback
#
#     drive-wheels engine-location  wheel-base  ...  engine-size  fuel-system  \
# ...

# %% [markdown]
# #**** Scatter Plot to Visualization the data

# %%
car_data.describe()
# Out:
#        symboling  losses  wheel-base  length  width  height  weight  \
# count     205.00  205.00      205.00  205.00 205.00  205.00  205.00
# mean        0.83  129.80       98.76  174.05  65.91   53.72 2555.57
# std         1.25   35.33        6.02   12.34   2.15    2.44  520.68
# min        -2.00   65.00       86.60  141.10  60.30   47.80 1488.00
# 25%         0.00  101.00       94.50  166.30  64.10   52.00 2145.00
# 50%         1.00  128.00       97.00  173.20  65.50   54.10 2414.00
# 75%         2.00  161.00      102.40  183.10  66.90   55.50 2935.00
# max         3.00  256.00      120.90  208.10  72.30   59.80 4066.00
#
#        engine-size  compression-ratio  horsepower  peak-rpm  city-mpg  \
# count       205.00             205.00      205.00    205.00    205.00
# mean        126.91              10.14      103.90   5129.02     25.22
# std          41.64               3.97       39.68    478.41      6.54
# min          61.00               7.00       48.00   4150.00     13.00
# ...

# %%
INPUT_FEATURE = "price" # Training
LABEL = "losses" # Target

plt.ylabel(LABEL)
plt.xlabel(INPUT_FEATURE)
plt.title("Scatter Plot ")

plt.scatter(car_data[INPUT_FEATURE], car_data[LABEL], c='red')

# %% [markdown]
# # New Section

# %% [markdown]
# # RMSE: Squared Loss and RMSE (Loss function Regression)
# . L2 Loss function (squared error )
# . L2 = (observation - prediction)^2
# . L2 = (Y-Y')^2

# %%
# polyfit(x,y, deg) used to fit polynomial of specified degree
x = car_data[INPUT_FEATURE]
y = car_data[LABEL] # observation target

opt = np.polyfit(x, y, 1) # optimal solution
print(opt)
# Out:
# [1.32153069e-03 1.12543252e+02]

# %% [markdown]
# . Goal: Is to train a model that minimizes RMSE (mean squared error)

# %%
y_pred = opt[0] * x + opt[1] #  Y' = mx + b

opt_rmse = math.sqrt(metrics.mean_squared_error(y_pred, y)) # The average difference btw Y' and Y
slope = opt[0]
bias = opt[1]
print("Optimal RMSE = ", opt_rmse, " for solution", opt)
# Out:
# Optimal RMSE =  33.65404199035883  for solution [1.32153069e-03 1.12543252e+02]

# %% [markdown]
# Visualizing a Linear Model Using a Scatter Plot

# %%
def scatter_plot(features, targets, slopes=[], biases=[], model_names=[]):
  colors = [cm.coolwarm(x) for x in np.linspace(0,1, len(slopes))]

  plt.ylabel("target")
  plt.xlabel("input feature")
  plt.title("Regression model")

  plt.scatter(features, targets, color = 'black', label="")

  for i in range (0, len(slopes)):
    y_0 = slopes[i] * features.min() + biases[i]
    y_1 = slopes[i] * features.max() + biases[i]
    plt.plot([features.min(), features.max()], [y_0, y_1],
             label=model_names[i], color=colors[i])
  if (len(model_names) > 0):
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
scatter_plot(car_data[INPUT_FEATURE], car_data[LABEL],
             [slope], [bias], ["optimal model"])
